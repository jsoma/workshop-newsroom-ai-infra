# %%
# Install required packages
# !pip install --quiet pandas

print('✓ Packages installed!')

# %% [markdown]
# # Analyzing real estate transfers
#
# We aren't doing anything fancy here! But it's just some data analysis we don't want to have to do for other people.

# %%
import pandas as pd
pd.options.display.max_columns = None

df = pd.read_csv("data/transfers.csv")
df.head()
# Out:
# /var/folders/25/h3prywj14qb0mlkl2s8bxq5m0000gn/T/ipykernel_81007/422507928.py:4: DtypeWarning: Columns (0: instrument_prefix) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/transfers.csv")
#    source_document_id             source_title  \
# 0                2446  2017 All Transfers XLSX
# 1                2446  2017 All Transfers XLSX
# 2                2446  2017 All Transfers XLSX
# 3                2446  2017 All Transfers XLSX
# 4                2446  2017 All Transfers XLSX
#
#                                           source_url source_period_type  \
# 0  https://www.spotsylvania.va.us/DocumentCenter/...          aggregate
# 1  https://www.spotsylvania.va.us/DocumentCenter/...          aggregate
# 2  https://www.spotsylvania.va.us/DocumentCenter/...          aggregate
# 3  https://www.spotsylvania.va.us/DocumentCenter/...          aggregate
# 4  https://www.spotsylvania.va.us/DocumentCenter/...          aggregate
#
#    source_year  source_start_month  source_end_month    source_schema  \
# 0         2017                   1                12  grantor_grantee
# 1         2017                   1                12  grantor_grantee
# 2         2017                   1                12  grantor_grantee
# 3         2017                   1                12  grantor_grantee
# 4         2017                   1                12  grantor_grantee
#
#   transfer_date transfer_date_parsed  transfer_year  transfer_month  \
# 0      01/03/17           2017-01-03           2017               1
# 1      01/03/17           2017-01-03           2017               1
# 2      01/03/17           2017-01-03           2017               1
# 3      01/03/17           2017-01-03           2017               1
# 4      01/03/17           2017-01-03           2017               1
#
#    parcel_id                                            grantor  \
# 0   22E1-67-              Otis A Bristow III or Wendy D Bristow
# 1  22T20-31-                                Marjorie G Schrader
# 2    23C2E1-  Joan Coleman & Theresa Coleman Trs The Coleman...
# 3    23C2E2-  Joan Coleman & Theresa Coleman Trs The Coleman...
# 4   23H7-61-                    Walter L Brown or Nedra G Brown
#
#                                     grantee  owner  owner_or_c_o  \
# 0                        Otis A Bristow III    NaN           NaN
# 1                          Jannie M Hillian    NaN           NaN
# 2  Christopher M Alward or Michael G Larson    NaN           NaN
# 3  Christopher M Alward or Michael G Larson    NaN           NaN
# 4                             Paula J Kelly    NaN           NaN
#
#    consideration  selling_price transfer_code transfer_description  deed_type  \
# 0              0            NaN             Q            Quitclaim        NaN
# 1         219900            NaN             S                 Sale        NaN
# 2         142000            NaN             M    Multiple Transfer        NaN
# 3         142000            NaN             M    Multiple Transfer        NaN
# 4         209000            NaN             S                 Sale        NaN
#
#    sale_type                                  physical_address  \
# 0        NaN          810 Kilarney DR Fredericksburg, VA 22407
# 1        NaN  12114 Meadow Branch WAY Fredericksburg, VA 22407
# 2        NaN             5704 Ross DR Fredericksburg, VA 22407
# 3        NaN             5706 Ross DR Fredericksburg, VA 22407
# 4        NaN      11517 Sturbridge CT Fredericksburg, VA 22407
#
#            city_state      zip instrument_id  acreage acreage_units  \
# 0  Fredericksburg, VA  22407.0       0000-97     0.00         Acres
# 1  Fredericksburg, VA  22407.0       0000-65  3740.00         Sq.Ft
# 2  Fredericksburg, VA  22407.0       0000-26     0.21         Acres
# 3  Fredericksburg, VA  22407.0       0000-26     0.21         Acres
# 4  Fredericksburg, VA  22407.0       0000-68  5009.00         Sq.Ft
#
#    assessment_land  assessment_building  assessment_improvements  \
# 0            75000                62400                    11600
# 1            70000               125900                    10500
# 2            55000                38700                    10100
# 3            27500                    0                        0
# 4            85000               102900                    10900
#
#    assessment_total     legal_description_1 legal_description_2  \
# 0            149000        Chancellor Green        Lot 67 Sec 1
# 1            206400  Oakview (Salem Fields)        Lot 31 Sec 3
# 2            103800             Thomas Ross       Lot 1 Block E
# 3             27500             Thomas Ross       Lot 2 Block E
# 4            198800              Summerlake        Lot 61 Sec 2
#
#    parcel_part_1 parcel_part_2 parcel_part_3 parcel_part_4 parcel_part_5  \
# 0             22             E             1             -            67
# 1             22             T            20             -            31
# 2             23             C             2             E             1
# 3             23             C             2             E             2
# 4             23             H             7             -            61
#
#   parcel_part_6  address_number address_unit    street_name street_suffix  \
# 0             -             810          NaN       Kilarney            DR
# 1             -           12114          NaN  Meadow Branch           WAY
# 2             -            5704          NaN           Ross            DR
# 3             -            5706          NaN           Ross            DR
# 4             -           11517          NaN     Sturbridge            CT
#
#   address_extra instrument_prefix  instrument_number
# 0           NaN               0.0                 97
# 1           NaN               0.0                 65
# 2           NaN               0.0                 26
# 3           NaN               0.0                 26
# 4           NaN               0.0                 68

# %%
df[df['source_year'] == 2017].head()
# Out:
#    source_document_id             source_title  \
# 0                2446  2017 All Transfers XLSX
# 1                2446  2017 All Transfers XLSX
# 2                2446  2017 All Transfers XLSX
# 3                2446  2017 All Transfers XLSX
# 4                2446  2017 All Transfers XLSX
#
#                                           source_url source_period_type  \
# 0  https://www.spotsylvania.va.us/DocumentCenter/...          aggregate
# 1  https://www.spotsylvania.va.us/DocumentCenter/...          aggregate
# 2  https://www.spotsylvania.va.us/DocumentCenter/...          aggregate
# 3  https://www.spotsylvania.va.us/DocumentCenter/...          aggregate
# 4  https://www.spotsylvania.va.us/DocumentCenter/...          aggregate
#
#    source_year  source_start_month  source_end_month    source_schema  \
# 0         2017                   1                12  grantor_grantee
# 1         2017                   1                12  grantor_grantee
# 2         2017                   1                12  grantor_grantee
# 3         2017                   1                12  grantor_grantee
# 4         2017                   1                12  grantor_grantee
#
#   transfer_date transfer_date_parsed  transfer_year  transfer_month  \
# 0      01/03/17           2017-01-03           2017               1
# 1      01/03/17           2017-01-03           2017               1
# 2      01/03/17           2017-01-03           2017               1
# 3      01/03/17           2017-01-03           2017               1
# 4      01/03/17           2017-01-03           2017               1
#
#    parcel_id                                            grantor  \
# 0   22E1-67-              Otis A Bristow III or Wendy D Bristow
# 1  22T20-31-                                Marjorie G Schrader
# 2    23C2E1-  Joan Coleman & Theresa Coleman Trs The Coleman...
# 3    23C2E2-  Joan Coleman & Theresa Coleman Trs The Coleman...
# 4   23H7-61-                    Walter L Brown or Nedra G Brown
#
#                                     grantee  owner  owner_or_c_o  \
# 0                        Otis A Bristow III    NaN           NaN
# 1                          Jannie M Hillian    NaN           NaN
# 2  Christopher M Alward or Michael G Larson    NaN           NaN
# 3  Christopher M Alward or Michael G Larson    NaN           NaN
# 4                             Paula J Kelly    NaN           NaN
#
#    consideration  selling_price transfer_code transfer_description  deed_type  \
# 0              0            NaN             Q            Quitclaim        NaN
# 1         219900            NaN             S                 Sale        NaN
# 2         142000            NaN             M    Multiple Transfer        NaN
# 3         142000            NaN             M    Multiple Transfer        NaN
# 4         209000            NaN             S                 Sale        NaN
#
#    sale_type                                  physical_address  \
# 0        NaN          810 Kilarney DR Fredericksburg, VA 22407
# 1        NaN  12114 Meadow Branch WAY Fredericksburg, VA 22407
# 2        NaN             5704 Ross DR Fredericksburg, VA 22407
# 3        NaN             5706 Ross DR Fredericksburg, VA 22407
# 4        NaN      11517 Sturbridge CT Fredericksburg, VA 22407
#
#            city_state      zip instrument_id  acreage acreage_units  \
# 0  Fredericksburg, VA  22407.0       0000-97     0.00         Acres
# 1  Fredericksburg, VA  22407.0       0000-65  3740.00         Sq.Ft
# 2  Fredericksburg, VA  22407.0       0000-26     0.21         Acres
# 3  Fredericksburg, VA  22407.0       0000-26     0.21         Acres
# 4  Fredericksburg, VA  22407.0       0000-68  5009.00         Sq.Ft
#
#    assessment_land  assessment_building  assessment_improvements  \
# 0            75000                62400                    11600
# 1            70000               125900                    10500
# 2            55000                38700                    10100
# 3            27500                    0                        0
# 4            85000               102900                    10900
#
#    assessment_total     legal_description_1 legal_description_2  \
# 0            149000        Chancellor Green        Lot 67 Sec 1
# 1            206400  Oakview (Salem Fields)        Lot 31 Sec 3
# 2            103800             Thomas Ross       Lot 1 Block E
# 3             27500             Thomas Ross       Lot 2 Block E
# 4            198800              Summerlake        Lot 61 Sec 2
#
#    parcel_part_1 parcel_part_2 parcel_part_3 parcel_part_4 parcel_part_5  \
# 0             22             E             1             -            67
# 1             22             T            20             -            31
# 2             23             C             2             E             1
# 3             23             C             2             E             2
# 4             23             H             7             -            61
#
#   parcel_part_6  address_number address_unit    street_name street_suffix  \
# 0             -             810          NaN       Kilarney            DR
# 1             -           12114          NaN  Meadow Branch           WAY
# 2             -            5704          NaN           Ross            DR
# 3             -            5706          NaN           Ross            DR
# 4             -           11517          NaN     Sturbridge            CT
#
#   address_extra instrument_prefix  instrument_number
# 0           NaN               0.0                 97
# 1           NaN               0.0                 65
# 2           NaN               0.0                 26
# 3           NaN               0.0                 26
# 4           NaN               0.0                 68

# %%
df['assessment_total'].median()
# Out:
# np.float64(176300.0)
